# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/Kelly/Documents/Documents/CS 234/week-14-day-24-tutorials-kellyc721/my_data/covid_articles_matched_qids.csv", encoding="utf-8", parse_dates=["date"])

# %%
df.head()
# Out:
#         date country_code       project  \
# 0 2023-02-07           FR  fr.wikipedia
# 1 2023-02-07           IN  mr.wikipedia
# 2 2023-02-07           TW  zh.wikipedia
# 3 2023-02-07           IN  en.wikipedia
# 4 2023-02-07           US  en.wikipedia
#
#                                    article        qid  pageviews
# 0              Maladie_Ã _coronavirus_2019  Q84263196         92
# 1  à¤à¥à¤°à¥à¤¨à¤¾à¤µà¥à¤¹à¤¾à¤¯à¤°à¤¸  Q57751738         90
# 2          2019å çç
# æ¯ç
# èºç£ç«æ
#   Q84081307        272
# 3           2019â20_coronavirus_pandemic  Q81068910        714
# 4                World_Health_Organization      Q7817       1278

# %%
df['article'] = df['article'].str.encode('latin1').str.decode('utf-8')

# %%
df['article'] = df['article'].str.replace('_', ' ')

# %%
df['article'].head()
# Out:
# 0      Maladie à coronavirus 2019
# 1                   कोरोनाव्हायरस
# 2                   2019冠狀病毒病臺灣疫情
# 3    2019–20 coronavirus pandemic
# 4       World Health Organization
# Name: article, dtype: object

# %%
df.to_csv("covid_articles_matched_qids.csv", index=False)
